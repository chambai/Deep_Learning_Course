# %% [markdown]
# <a href="https://colab.research.google.com/github/chambai/Deep_Learning_Course/blob/main/Week%202%20DL%20Image%20Analysis%201/LeNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Implementations of LeNet Deep Neural Network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Can you apply techniques to reduce overfitting?
